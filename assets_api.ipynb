# %%
import requests

apikey = "MATHQIA7QGZQ195N"

keywords = "SWDA"

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = f'https://www.alphavantage.co/query?function=SYMBOL_SEARCH&keywords={keywords}&apikey={apikey}'
r = requests.get(url)
data = r.json()
data
# Out:
# {'bestMatches': [{'1. symbol': 'SWDAF',
#    '2. name': 'Software AG',
#    '3. type': 'Equity',
#    '4. region': 'United States',
#    '5. marketOpen': '09:30',
#    '6. marketClose': '16:00',
#    '7. timezone': 'UTC-04',
#    '8. currency': 'USD',
#    '9. matchScore': '0.8889'},
#   {'1. symbol': 'SWDA.LON',
#    '2. name': 'iShares Core MSCI World UCITS ETF USD (Acc)',
#    '3. type': 'ETF',
#    '4. region': 'United Kingdom',
#    '5. marketOpen': '08:00',
#    '6. marketClose': '16:30',
#    '7. timezone': 'UTC+01',
#    '8. currency': 'GBX',
#    '9. matchScore': '0.8000'}]}

# %%
# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = f'https://www.alphavantage.co/query?function=GLOBAL_QUOTE&symbol=SWDA.LON&apikey={apikey}'
r = requests.get(url)
data = r.json()

print(data)
# Out:
# {'Global Quote': {'01. symbol': 'SWDA.LON', '02. open': '6717.0000', '03. high': '6750.0000', '04. low': '6700.0000', '05. price': '6745.0000', '06. volume': '72789', '07. latest trading day': '2023-11-10', '08. previous close': '6745.0000', '09. change': '0.0000', '10. change percent': '0.0000%'}}
