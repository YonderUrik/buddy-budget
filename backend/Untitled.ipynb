# %%
nums = [-3,4,3,90]
target = 0

for indexOne, valueOne in enumerate(nums):
    print(indexOne)
    for indexTwo, valueTwo in enumerate(nums[indexOne+1:]):
        print(valueTwo + valueOne)
        if valueTwo + valueOne == target:
            print([indexOne, indexOne+indexTwo+1])
# Out:
# 0
# 1
# 0
# [0, 2]
# 87
# 1
# 7
# 94
# 2
# 93
# 3
