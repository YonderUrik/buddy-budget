# %%
import requests

apikey = "jpRdLh4GmFhJLlswnnzMSVyDVfkkqkDq"

#keywords = "iShares Core Msci World UCITS ETF"
keywords = "iShares Core Msci World UCITS ETF USD "

url = f'https://api.polygon.io/v3/reference/tickers?search={keywords}&apiKey={apikey}&limit=1000'
r = requests.get(url)
print(r)
print(r.status_code)
data = r.json()
data['results
# Out:
# <Response [200]>
# 200
# {'results': [{'ticker': 'ISMCF',
#    'name': 'ISHARES MSCI US UCITS ETF',
#    'market': 'otc',
#    'locale': 'us',
#    'type': 'ETF',
#    'active': True,
#    'currency_name': 'USD',
#    'last_updated_utc': '2023-07-31T12:29:23.387Z'},
#   {'ticker': 'IEDMF',
#    'name': 'ISHARES MSCI WORLD ESG',
#    'market': 'otc',
#    'locale': 'us',
#    'type': 'ETF',
#    'active': True,
#    'currency_name': 'USD',
#    'last_updated_utc': '2023-04-03T06:43:03.863Z'},
#   {'ticker': 'IRSVF',
#    'name': 'ISHARES V MSCI WORLD',
#    'market': 'otc',
#    'locale': 'us',
#    'type': 'ETF',
#    'active': True,
#    'currency_name': 'USD',
#    'last_updated_utc': '2023-05-23T18:53:40.351Z'},
#   {'ticker': 'IWVUF',
#    'name': 'ISHARES EDGE MSCI WORLD',
#    'market': 'otc',
#    'locale': 'us',
#    'type': 'ETF',
#    'active': True,
#    'currency_name': 'USD',
#    'last_updated_utc': '2021-10-08T08:45:19.615Z'},
#   {'ticker': 'IIREF',
# ...

# %%
data['results']
# Out:
# [{'ticker': 'ISMCF',
#   'name': 'ISHARES MSCI US UCITS ETF',
#   'market': 'otc',
#   'locale': 'us',
#   'type': 'ETF',
#   'active': True,
#   'currency_name': 'USD',
#   'last_updated_utc': '2023-07-31T12:29:23.387Z'},
#  {'ticker': 'IEDMF',
#   'name': 'ISHARES MSCI WORLD ESG',
#   'market': 'otc',
#   'locale': 'us',
#   'type': 'ETF',
#   'active': True,
#   'currency_name': 'USD',
#   'last_updated_utc': '2023-04-03T06:43:03.863Z'},
#  {'ticker': 'IRSVF',
#   'name': 'ISHARES V MSCI WORLD',
#   'market': 'otc',
#   'locale': 'us',
#   'type': 'ETF',
#   'active': True,
#   'currency_name': 'USD',
#   'last_updated_utc': '2023-05-23T18:53:40.351Z'},
#  {'ticker': 'IWVUF',
#   'name': 'ISHARES EDGE MSCI WORLD',
#   'market': 'otc',
#   'locale': 'us',
#   'type': 'ETF',
#   'active': True,
#   'currency_name': 'USD',
#   'last_updated_utc': '2021-10-08T08:45:19.615Z'},
#  {'ticker': 'IIREF',
#   'name': 'ISHARES MSCI WORLD ORD',
#   'market': 'otc',
#   'locale': 'us',
# ...

# %%
[doc for doc in data['results'] if 'EIM' in doc['ticker']]
# Out:
# []
